# %%
## PUT THIS ALL IN ONE CELL!

import cv2
import numpy as np
import time

# Connects to your computer's default camera
cap = cv2.VideoCapture(0)


# Automatically grab width and height from video feed
# (returns float which we need to convert to integer for later on!)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))


font                   = cv2.FONT_HERSHEY_SIMPLEX
count = 0

kernel= np.ones(shape=(3,3), dtype=np.float32)

start = time.time()
time.clock()    
elapsed = 0

while True:
    
    # Capture frame-by-frame
    ret, frame = cap.read()

    # Our operations on the frame come here
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # soboly = cv2.Sobel(src=frame, ddepth=cv2.CV_16S, dx=0, dy=1, ksize=5)
    # sobolx = cv2.Sobel(src=frame, ddepth=cv2.CV_16S, dx=1, dy=0, ksize=5)
    # blended = cv2.addWeighted(src1=sobolx, alpha=0.5, src2=soboly, beta=0.5, gamma=0)
    # gradient = cv2.morphologyEx(src=blended, op=cv2.MORPH_GRADIENT, kernel=kernel)
    ret, thres = cv2.threshold(gray,127,255,cv2.THRESH_BINARY)
    
    # fps = str(cap.get(cv2.CAP_PROP_FPS))
    count += 1
    elapsed = time.time() - start
    fps = count / elapsed

    #drawing
    cv2.putText(thres,  
                str(fps),  
                (100, 100),  
                font, 1,  
                (0, 0, 0),  
                2,  
                cv2.LINE_4)
    # Display the resulting frame
    cv2.imshow('frame',thres)
    
    # This command let's us quit with the "q" button on a keyboard.
    # Simply pressing X on the window won't work!
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# When everything done, release the capture and destroy the windows
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import time

capture = cv2.VideoCapture(0)
width = int(capture.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(capture.get(cv2.CAP_PROP_FRAME_HEIGHT))

writer = cv2.VideoWriter('../DATA/My_Capture.mp4', cv2.VideoWriter_fourcc(*'DIVX'),25, (width, height), 0)

font = cv2.FONT_HERSHEY_SIMPLEX
start = time.time()
time.clock()
elapsed=0
count = 0

while True:
    ret, frame = capture.read()
    elapsed = time.time() - start
    count += 1
    fps = count / elapsed

    new_frame = cv2.cvtColor(src=frame, code=cv2.COLOR_BGR2GRAY)
    cv2.putText(img=new_frame, text=str(round(fps,2)), org=(10,50), fontFace=font, fontScale=2, color=(255,255,255), thickness=2, lineType=cv2.LINE_4)
    writer.write(new_frame)    
    cv2.imshow('Video',new_frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

writer.release()
capture.release()
cv2.destroyAllWindows()

# %%
pwd
# Out:
# &#39;c:\\Users\\nicov\\Documents\\GitHub\\python-cvcourse\\03-Video-Basics&#39;

# %%
import cv2

capture = cv2.VideoCapture(0)

width = int(capture.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(capture.get(cv2.CAP_PROP_FRAME_HEIGHT))

# TOP Left corner
x = width // 2
y = height // 2

# width height rectangle
w_rec = width // 4
h_rec = height // 4

#bottom right = x + w, y , h

while True:
        ret, frame = capture.read()

        cv2.rectangle(frame, (x,y), (x+w_rec, y+h_rec), color=(0, 0, 255), thickness=4)

        cv2.imshow('video', frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

capture.release()
cv2.destroyAllWindows()

# %%
import cv2

# callback for drawing rectangle
def draw_rectangle(event, x, y, flags, param):
    global pt1, pt2, top_left_clicked, bot_right_clicked
    
    if event == cv2.EVENT_LBUTTONDOWN:

        #reset
        if top_left_clicked == True and bot_right_clicked == True:
            pt1 = (0,0)
            pt2 = (0,0)
            top_left_clicked = False
            bot_right_clicked = False
        
        if top_left_clicked == False:
            pt1 = (x,y)
            top_left_clicked = True
        
        elif bot_right_clicked == False:
            pt2 = (x,y)
            bot_right_clicked = True


# Global vars
pt1 = (0,0)
pt2 = (0,0)
top_left_clicked = False
bot_right_clicked = False

# connect to fallback
capture = cv2.VideoCapture(0)

cv2.namedWindow('test')
cv2.setMouseCallback('test', draw_rectangle)

width = int(capture.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(capture.get(cv2.CAP_PROP_FRAME_HEIGHT))

# TOP Left corner
x = width // 2
y = height // 2

# width height rectangle
w_rec = width // 4
h_rec = height // 4

#bottom right = x + w, y , h

while True:
    ret, frame = capture.read()

    # draw on the frame with rectange
    if top_left_clicked == True:
        cv2.circle(frame, center=pt1, radius=5, color=(0, 0, 255), thickness=-1)

    if top_left_clicked == True and bot_right_clicked == True:
        cv2.rectangle(frame, pt1=pt1, pt2=pt2, color=(0, 0, 255), thickness=5)

    cv2.imshow('test', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

capture.release()
cv2.destroyAllWindows()
